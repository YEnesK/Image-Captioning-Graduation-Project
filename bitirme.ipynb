# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/NeGoruyorsun
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/.shortcut-targets-by-id/1npzd5q4bNBenBMxC0PWcnVTg9kpeZliT/NeGoruyorsun

# %%
# !pip install -r requirements.txt

# %%
# !pip install git+https://github.com/openai/CLIP.git

# %%
# !pip install rouge_score

# %%
# !python ImageCaptioning/single_test_cosmos.py
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# Candidate Caption:  Gece bir şehir sokağında yürüyen bir kişi.
# Reference Caption:  İnsanlar dolaşırken ve binalar aydınlandığında geceleri bir sokakta.
# BLEU4:  0.028051604056085533
# BLEU3:  0.03248071373371268
# METEOR:  0.06329113924050632
# ROUGE-L:  0.17391304347826086
#
#
# Reference Caption:  Birçok sokak aydınlatmalı binaya sahip bir şehir sokağı.
# BLEU4:  0.07103125716740531
# BLEU3:  0.08729019475622869
# METEOR:  0.12658227848101264
# ROUGE-L:  0.28571428571428564
#
#
# Reference Caption:  Yoğun bir şehir sokağı, yabancı bir ülkede gece aydınlandı.
# BLEU4:  0.06814441179181165
# BLEU3:  0.0865034660176716
# ...

# %%
# !python ImageCaptioning/single_test.py
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/modeling_auto.py:1712: FutureWarning: The class `AutoModelWithLMHead` is deprecated and will be removed in a future version. Please use `AutoModelForCausalLM` for causal language models, `AutoModelForMaskedLM` for masked language models and `AutoModelForSeq2SeqLM` for encoder-decoder models.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# Candidate Caption:  Gece bir şehir sokağı trafik dolu.
# ...

# %%
# !unzip images_data.zip -d /content/drive/MyDrive/NeGoruyorsun
# Out:
# Archive:  images_data.zip

# %%
import torch
torch.cuda.empty_cache()

# %%
# !python ImageCaptioning/train_cosmos.py
# Out:
# tokenizer_config.json: 100% 537/537 [00:00<00:00, 4.34MB/s]
# vocab.json: 100% 927k/927k [00:00<00:00, 2.02MB/s]
# merges.txt: 100% 585k/585k [00:00<00:00, 1.35MB/s]
# tokenizer.json: 100% 2.37M/2.37M [00:00<00:00, 3.41MB/s]
# special_tokens_map.json: 100% 438/438 [00:00<00:00, 3.60MB/s]
# 100%|████████████████████████████████████████| 338M/338M [00:03<00:00, 116MiB/s]
# total epoch:6
# config.json: 100% 893/893 [00:00<00:00, 7.13MB/s]
# model.safetensors: 100% 498M/498M [00:02<00:00, 248MB/s]
# generation_config.json: 100% 132/132 [00:00<00:00, 1.31MB/s]
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:588: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# >>> Training epoch 0
# ...

# %%
# !python ImageCaptioning/train.py
# Out:
# tokenizer_config.json: 100% 595/595 [00:00<00:00, 4.66MB/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json: 100% 720/720 [00:00<00:00, 6.65MB/s]
# vocab.json: 100% 1.04M/1.04M [00:00<00:00, 10.4MB/s]
# merges.txt: 100% 594k/594k [00:00<00:00, 11.0MB/s]
# special_tokens_map.json: 100% 357/357 [00:00<00:00, 3.76MB/s]
# total epoch:6
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/modeling_auto.py:1712: FutureWarning: The class `AutoModelWithLMHead` is deprecated and will be removed in a future version. Please use `AutoModelForCausalLM` for causal language models, `AutoModelForMaskedLM` for masked language models and `AutoModelForSeq2SeqLM` for encoder-decoder models.
#   warnings.warn(
# ...

# %%
# !pip install transformers

# %%
# !pip install nltk
# !pip install git+https://github.com/salaniz/pycocoevalcap
# Out:
# ...
#   Cloning https://github.com/salaniz/pycocoevalcap to /tmp/pip-req-build-a0382wsl
#   Running command git clone --filter=blob:none --quiet https://github.com/salaniz/pycocoevalcap /tmp/pip-req-build-a0382wsl
#   Resolved https://github.com/salaniz/pycocoevalcap to commit a24f74c408c918f1f4ec34e9514bc8a76ce41ffd
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pycocoevalcap: filename=pycocoevalcap-1.2-py3-none-any.whl size=104312246 sha256=bdbc6419694b8a0e07b81efbcd389f2a9b40762274383d5a51c98fccf7c26f5a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-r1nkzxpn/wheels/43/54/73/3e2c6d4ace7657958cde52ac6fd47b342cd4aae5a7aa4fcbf9
# Successfully built pycocoevalcap
# ...

# %%
# !python ImageCaptioning/testn_cosmos.py "1k_cosmos"
# Out:
#   0% 0/16000 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# 100% 16000/16000 [50:39<00:00,  5.26it/s]
# Metin üretimi tamamlandı ve sonuçlar model_1k_cosmos_test_result.json dosyasına kaydedildi.

# %%
# !python ImageCaptioning/test.py
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/modeling_auto.py:1712: FutureWarning: The class `AutoModelWithLMHead` is deprecated and will be removed in a future version. Please use `AutoModelForCausalLM` for causal language models, `AutoModelForMaskedLM` for masked language models and `AutoModelForSeq2SeqLM` for encoder-decoder models.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
#
#
# Bir otoparkta birbirine bitişik olarak park edilen üç otobüs.

# %%
# !python ImageCaptioning/test_cosmos.py
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
#
#
# Bir otoparkta park edilen sarı ve mavi otobüslerden oluşan bir grup.
